# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/wine_dataset.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  alcohol  quality  style
# 0            7.4              0.70         0.00  ...      9.4        5    red
# 1            7.8              0.88         0.00  ...      9.8        5    red
# 2            7.8              0.76         0.04  ...      9.8        5    red
# 3           11.2              0.28         0.56  ...      9.8        6    red
# 4            7.4              0.70         0.00  ...      9.4        5    red
#
# [5 rows x 13 columns]

# %%
df['style'] = df['style'].replace('red', 0)

# %%
df['style'] = df['style'].replace('white', 1)

# %%
y = df['style'] #alvo
x = df.drop('style', axis=1)#preditivas, tudo menos a variavel alvo

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
#TAMANHO
print ('X_train: numero de linhas e colunas: {}'.format(X_train.shape))
print ('X_test: numero de linhas e colunas: {}'.format(X_test.shape))
print ('y_train: numero de linhas e colunas: {}'.format(y_train.shape))
print ('y_test: numero de linhas e colunas: {}'.format(y_test.shape))
# Out:
# X_train: numero de linhas e colunas: (4547, 12)
# X_test: numero de linhas e colunas: (1950, 12)
# y_train: numero de linhas e colunas: (4547,)
# y_test: numero de linhas e colunas: (1950,)

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelo = ExtraTreesClassifier()
modelo.fit(X_train,y_train)#modelo treinado

resultado = modelo.score(X_test,y_test)#agora podemos testar
print('Acuracia: ',resultado) #porcentagem de performace do modelo
# Out:
# Acuracia:  0.9958974358974358

# %%
y_test[400:403]
# Out:
# 4459    1
# 1412    0
# 4725    1
# Name: style, dtype: int64

# %%
X_test[400:403]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  ...  sulphates  alcohol  quality
# 4459            7.3              0.21         0.33  ...       0.52     10.2        6
# 1412            8.2              0.24         0.34  ...       0.94     10.9        6
# 4725            7.2              0.17         0.37  ...       0.46     11.0        7
#
# [3 rows x 12 columns]

# %%
previsoes = modelo.predict(X_test[400:403])

# %%
previsoes
# Out:
# array([1, 0, 1])

# %%
prev = modelo.predict(X_test)

# %%
import math
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
prev
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
rmse = (np.sqrt(mean_squared_error(y_test, previsoes)))

# %%
print ('Performance do modelo avaliado com os dados de teste:')
print('\nRMSE é: {} '.format(rmse))
# Out:
# Performance do modelo avaliado com os dados de teste:
#
# RMSE é: 0.0
